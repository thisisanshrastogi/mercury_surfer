# %%
import pandas as pd;

# %%
df = pd.read_csv('./sentiment_classified.csv')

# %%
df.shape
# Out:
# (71769, 10)

# %%
df.sample(5)
# Out:
#                                                   Review        Date  Stars  \
# 38044  Unable to receive zelle code or sms codes from...  2025-04-17      5
# 27458  Forcing me to update the app, yet it won't let...  2024-09-28      3
# 19018  I am so sick of being told you are diligently ...  2025-05-10      5
# 69944  Bill Pay Payee history in payment section is i...  2024-06-08      3
# 17894  Ever since that big update about 6 or 7 months...  2025-05-09      4
#
#                                          Cleaned Reviews    neg    neu    pos  \
# 38044  unable receive zelle code sm code app via web ...  0.000  1.000  0.000
# 27458  force update app yet let update say app compat...  0.000  1.000  0.000
# 19018         sick tell diligently work fix app FIX well  0.129  0.719  0.152
# 69944  Bill Pay Payee history payment section inconsi...  0.108  0.782  0.110
# 17894     ever since big update month ago absolute trash  0.000  1.000  0.000
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 71769 entries, 0 to 71768
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Review           71769 non-null  object
#  1   Date             71769 non-null  object
#  2   Stars            71769 non-null  int64
#  3   Cleaned Reviews  71231 non-null  object
#  4   neg              71769 non-null  float64
#  5   neu              71769 non-null  float64
#  6   pos              71769 non-null  float64
#  7   compound         71769 non-null  float64
#  8   vader_label      71769 non-null  object
#  9   star_sentiments  71769 non-null  int64
# dtypes: float64(4), int64(2), object(4)
# memory usage: 5.5+ MB

# %%
df.isnull().sum()
# Out:
# Review               0
# Date                 0
# Stars                0
# Cleaned Reviews    538
# neg                  0
# neu                  0
# pos                  0
# compound             0
# vader_label          0
# star_sentiments      0
# dtype: int64

# %%
df.describe()
# Out:
#               Stars           neg           neu           pos      compound  \
# count  71769.000000  71769.000000  71769.000000  71769.000000  71769.000000
# mean       3.628071      0.106830      0.749521      0.142660      0.001547
# std        1.283318      0.164622      0.247923      0.233313      0.471563
# min        1.000000      0.000000      0.000000      0.000000     -0.985500
# 25%        3.000000      0.000000      0.661000      0.000000     -0.383700
# 50%        4.000000      0.046000      0.808000      0.043000      0.000000
# 75%        5.000000      0.155000      0.928000      0.169000      0.419900
# max        5.000000      1.000000      1.000000      1.000000      0.994700
#
#        star_sentiments
# count     71769.000000
# mean          1.116889
# std           0.732375
# min           0.000000
# 25%           1.000000
# 50%           1.000000
# 75%           2.000000
# max           2.000000

# %%
df.duplicated().sum()
# Out:
# 642

# %%
df.drop_duplicates()
# Out:
#                                                   Review        Date  Stars  \
# 0      24 May 2025 It’s stopped working! Every time I...  2025-05-24      1
# 1      closed my account a day after I created it and...  2025-05-24      1
# 2      Constantly freezes up my phone. it doesn't wor...  2025-05-23      1
# 3      horrible experience. spended 30 mins just to l...  2025-05-23      1
# 4      app never lets me in the first time, always ha...  2025-05-23      1
# ...                                                  ...         ...    ...
# 71764                                          very good  2024-12-18      5
# 71765                                     Great Services  2024-12-18      5
# 71766    no problems...online banking makes life easier!  2024-12-18      5
# 71767                                             luv <3  2024-12-16      5
# 71768                                           Not sure  2024-12-16      5
#
# ...

# %%
df.corr()['Stars']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.corr()['Stars']
#
# File ~/Documents/internship/mercury_surfer/venv/lib/python3.11/site-packages/pandas/core/frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~/Documents/internship/mercury_surfer/venv/lib/python3.11/site-packages/pandas/core/frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...
